# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('1_The_Schedule_of_GE_to_Lok_Sabha_ii_0.csv')
df.plot(kind='bar', x='States and Union Territories', y='No. Of Phases')
plt.show()
